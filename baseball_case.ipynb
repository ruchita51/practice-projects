# %%
#import the requred library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#upload the dataset or file
data=pd.read_csv("baseball_case.csv")

# %%
#print the data with head function 
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#this is classification problem

# %% [markdown]
# #for more understand the columns we can understand by  name of fullform .

# %% [markdown]
#  #Win,Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs,
# Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors

# %% [markdown]
# # win(w) is our target variable

# %%
#convert the data in to dataframe
data=pd.DataFrame(data)

# %%
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#by the info function we can chech the information about data like index colm ,name,nullvalue,and datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#by the dtypes we can check the columns type like ti is numeric integer or object 
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#by key function we can check the columns name
data.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#by isnull i can check the null values that are present in my dataset and sum will provide the total values of null
#in this dataset no null value present
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# no null values in data set

# %% [markdown]
# # statistical summary

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # describe function is explain all statistic values like minimum value,maximum values and also discribe mean standard deviation
# #75 percentile,25percentile,50 percentile,

# %%
data.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#we can batter understand the correlation by heatmap
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #RA,ER,ERA have strong corrilation,also H,AB also have positive corrilation
# #in this the lighter colour shows positive correlation and darker colour show the nagative correlation

# %% [markdown]
# data visualization

# %%
# Plotting distribution of winings matches 
plt.hist(data['W'])
plt.xlabel('Wininig matches')
plt.title('Distribution of Wins match')
# Out:
# Text(0.5, 1.0, 'Distribution of Wins match')

# %%
sns.pairplot(data)
plt.savefig("pairplot.png")
plt.show()

# %%
plt.scatter(data['W'], data['R'])
plt.title('Wins Scatter Plot')
plt.xlabel('Wins')
plt.ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %% [markdown]
# we can see in the scatter plot few matches are play abou the 800runs and win most of game win under 600-800 runs

# %%
sns.boxplot(y="W",data=data)
# Out:
# <AxesSubplot:ylabel='W'>

# %%
data.plot(kind='box',subplots=True,layout=(10,3),figsize=(25,25))
# Out:
# W         AxesSubplot(0.125,0.816017;0.227941x0.0639831)
# R      AxesSubplot(0.398529,0.816017;0.227941x0.0639831)
# AB     AxesSubplot(0.672059,0.816017;0.227941x0.0639831)
# H         AxesSubplot(0.125,0.739237;0.227941x0.0639831)
# 2B     AxesSubplot(0.398529,0.739237;0.227941x0.0639831)
# 3B     AxesSubplot(0.672059,0.739237;0.227941x0.0639831)
# HR        AxesSubplot(0.125,0.662458;0.227941x0.0639831)
# BB     AxesSubplot(0.398529,0.662458;0.227941x0.0639831)
# SO     AxesSubplot(0.672059,0.662458;0.227941x0.0639831)
# SB        AxesSubplot(0.125,0.585678;0.227941x0.0639831)
# RA     AxesSubplot(0.398529,0.585678;0.227941x0.0639831)
# ER     AxesSubplot(0.672059,0.585678;0.227941x0.0639831)
# ERA       AxesSubplot(0.125,0.508898;0.227941x0.0639831)
# CG     AxesSubplot(0.398529,0.508898;0.227941x0.0639831)
# SHO    AxesSubplot(0.672059,0.508898;0.227941x0.0639831)
# SV        AxesSubplot(0.125,0.432119;0.227941x0.0639831)
# ...

# %%
#by the box plot we can esaly understand the outliers

# %%
#in run boxplot have outlier its above 850runs

# %%
#in SV and E also have outliers

# %%
sns.regplot(x='R',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
# Run and win are linearly correlated

# %%
sns.histplot(x='R',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %%
sns.distplot(data["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.regplot(x='AB',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
# At balls is very weekly related to Wins

# %%
sns.histplot(x='AB',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %%
sns.regplot(x='H',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.histplot(x='H',data=data,kde=True)  # Hits are also very weekly related to wins
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %%
sns.regplot(x='2B',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
#Doubles are linearly related with Wins

# %%
sns.histplot(x='2B',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %%
# in histplot left skewness present

# %%
sns.regplot(x='3B',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
#Triple(3B) has very weak negative correlations with wins

# %%
sns.histplot(x='3B',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %%
#right-skewed present in this

# %%
sns.regplot(x='HR',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
#The home run has a very low correlation with wins

# %%
sns.histplot(x='HR',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %%
#right skwed the data

# %%
sns.regplot(x='BB',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
#WALK is psitive corration with wins but ist very light

# %%
sns.histplot(x='BB',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %%
#some skweness present in thi

# %%
sns.regplot(x='SO',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
#stricout have no relation with wins

# %%
sns.histplot(x='SO',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %%
#data have some left-skewed

# %%
sns.regplot(x='SB',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
#Stolen Bases is not correlated to win its slit nagative correlation

# %%
sns.histplot(x='SB',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %%
#Stolen Bases have some right skewed

# %%
sns.regplot(x='RA',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
#HIGHLY  NAGATIVE CORRRELATED

# %%
sns.histplot(x='RA',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %%
#NO SKEWED

# %%
sns.regplot(x='ER',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
#HIGLY NAGATIVE CORRELATED TO WINS

# %%
sns.histplot(x='ER',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %%
#no skewed

# %%
sns.regplot(x='ERA',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
#nagative correlation with wins

# %%
sns.histplot(x='ERA',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %%
#no skewed

# %%
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
sns.regplot(x='CG',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
#is not correlated to win

# %%
sns.histplot(x='CG',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %% [raw]
# #right skewed

# %%
sns.regplot(x='SHO',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
#Shutouts are highly correlated to win

# %%
sns.histplot(x='SHO',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %%
#no skew

# %%
sns.regplot(x='SV',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
#Saves are lightly correlated to win

# %%
sns.histplot(x='SV',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %%
#no skewed

# %%
sns.regplot(x='E',y='W',data=data)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
#Erroe is not releted to win

# %%
sns.histplot(x='E',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %%
#right skewed

# %% [markdown]
# # SUMMARY OF THE ABOVE ANALYSIS IS

# %%
#The number of runs, home runs, doubles, Saves, Shutouts, and Walks are highly positively linearly correlated.

# %%
#Earned Run Average, Runs Allowed, Earned Runs are highly negative linearly correlated

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
data.shape
# Out:
# (30, 17)

# %% [markdown]
# there is remove one line there are outlies present

# %%
#split into dependent indipendent variable y is dependent x is independent
y=data.iloc[:,0]

# %%
x=data.iloc[:,1:]

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
y=y.values.reshape(-1,1)  #reshape the data becouse its 1D(one dimantion array)

# %%
y
# Out:
# array([[ 95],
#        [ 83],
#        [ 81],
#        [ 76],
#        [ 74],
#        [ 93],
#        [ 87],
#        [ 81],
#        [ 80],
#        [ 78],
#        [ 88],
#        [ 86],
#        [ 85],
#        [ 76],
#        [ 68],
#        [100],
#        [ 98],
#        [ 97],
#        [ 68],
#        [ 64],
#        [ 90],
#        [ 83],
#        [ 71],
#        [ 67],
#        [ 63],
#        [ 92],
#        [ 84],
#        [ 79],
#        [ 74],
#        [ 68]], dtype=int64)

# %% [markdown]
# scaling the data

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
x = sc_x.fit_transform(x)
y = sc_y.fit_transform(y)

# %% [markdown]
# transformation of data

# %%
Q1 = data.quantile(.25, axis = 0)

# %%
Q3 = data.quantile(.75, axis = 0)

# %%
IQR = Q3-Q1

# %%
IQR
# Out:
# W       13.7500
# R       67.0000
# AB     106.0000
# H       88.5000
# 2B      26.5000
# 3B      16.0000
# HR      36.7500
# BB      73.0000
# SO     154.0000
# SB      27.5000
# RA      96.2500
# ER      92.0000
# ERA      0.5375
# CG       4.7500
# SHO      4.0000
# SV       9.5000
# E       10.7500
# dtype: float64

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
x = sc_x.fit_transform(x)
y = sc_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=.33,random_state=42)

# %%
train_x.shape
# Out:
# (20, 16)

# %%
test_x.shape
# Out:
# (10, 16)

# %% [markdown]
# apply the model

# %%
from sklearn import preprocessing


lab_enc = preprocessing.LabelEncoder()
y = lab_enc.fit_transform(test_y)

# %%
test_y
# Out:
# array([[-0.1913518 ],
#        [ 1.85189622],
#        [-1.3589221 ],
#        [ 1.56000365],
#        [-0.09405427],
#        [-0.28864932],
#        [-0.67783942],
#        [-1.74811219],
#        [ 0.39243335],
#        [ 1.3654086 ]])

# %% [markdown]
# impoert requred library

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

# %%
knn=KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(train_x,train_y)
#y_pred=knn.predict(test_x)
#print(confusion_matrix(test_y,y_pred))

# %%
#print("confusion_matrics",confusion_matrix(test_y,np.argmax(y_pred,axis=0)))

# %%
from sklearn.metrics import mean_squared_error

# %%
#def clf(model,x,y,x_test,y_test):
lr=LinearRegression()
lr.fit(x, y)
y_pred=lr.predict(test_x)
print( "MAE",mean_absolute_error(test_y,y_pred))
print("MSE" , mean_squared_error(test_y,y_pred))
#print("MMSE", metrics.mean_squared_error(test_y,y_pred))
# Out:
# MAE 0.2191160092080331
# MSE 0.07973756350394622

# %%
from sklearn.svm import SVC

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=[DecisionTreeClassifier(),SVC(),LogisticRegression()]
for m in model:
    m.fit(train_x,train_y)
    m.score(train_x,train_y)
    predm=m.predict(test_x)
    #print(confusion_matrix(test_y,y_predm))
    #print(accuracy_score(test_y,y_predm))
    #print(classification_report(y_test,y_predm))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-323-12cf3afd0f29> in <module>
#       1 model=[DecisionTreeClassifier(),SVC(),LogisticRegression()]
#       2 for m in model:
# ----> 3     m.fit(train_x,train_y)
#       4     m.score(train_x,train_y)
#       5     predm=m.predict(test_x)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     201
#     202         if is_classification:
# --> 203             check_classification_targets(y)
#     204             y = np.copy(y)
#     205
#
# ...

# %%
# Out:
# array([[ 1.3654086 ],
#        [ 0.1978383 ],
#        [ 0.00324325],
#        [-0.48324437],
#        [-0.67783942],
#        [ 1.17081355],
#        [ 0.5870284 ],
#        [ 0.00324325],
#        [-0.09405427],
#        [-0.28864932],
#        [ 0.68432592],
#        [ 0.48973087],
#        [ 0.39243335],
#        [-0.48324437],
#        [-1.26162457],
#        [ 1.85189622],
#        [ 1.65730117],
#        [ 1.56000365],
#        [-1.26162457],
#        [-1.65081467],
#        [ 0.87892097],
#        [ 0.1978383 ],
#        [-0.969732  ],
#        [-1.3589221 ],
#        [-1.74811219],
#        [ 1.07351602],
#        [ 0.29513583],
#        [-0.1913518 ],
#        [-0.67783942],
#        [-1.26162457]])

# %%
# Out:
# array([[-0.67783942],
#        [ 1.65730117],
#        [ 1.17081355],
#        [-0.48324437],
#        [ 0.48973087],
#        [-0.969732  ],
#        [ 0.1978383 ],
#        [ 0.00324325],
#        [ 1.07351602],
#        [-0.48324437],
#        [ 0.1978383 ],
#        [ 0.29513583],
#        [-1.26162457],
#        [-1.26162457],
#        [ 0.87892097],
#        [ 0.00324325],
#        [ 0.68432592],
#        [-1.26162457],
#        [-1.65081467],
#        [ 0.5870284 ]])
