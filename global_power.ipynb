# %%
#import the requred library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#load the data
data=pd.read_csv("global_power_plant.csv")

# %%
data.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
data.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
data.shape
# Out:
# (907, 27)

# %%
sns.heatmap(data.corr().isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# by this graph we can easly understand the null values

# %%
data.sample(10)
# Out:
#     country country_long                              name   gppd_idnr  \
# 269     IND        India            Hirewaddatti Wind Farm  WRI1026071
# 320     IND        India                            KANHER  IND0000179
# 865     IND        India                          VAITARNA  IND0000493
# 807     IND        India                           TILLAYA  IND0000456
# 827     IND        India  Talcher Kaniha Solar Power Plant  WRI1026215
# 571     IND        India                           PANIPAT  IND0000321
# 882     IND        India                     VISHNU PRAYAG  IND0000505
# 385     IND        India                 KUTTIYADI Add ext  IND0000226
# 486     IND        India                    MSPL Wind Farm  WRI1026070
# 653     IND        India                             ROPAR  IND0000380
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 269         49.0   15.1997    75.7620         Wind         NaN         NaN
# ...

# %%
data.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %%
data.head(5)
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %% [markdown]
# generation_gwh_2019,  estimated_generation_gwh,   generation_gwh_2013,  wepp_id,   other_fuel3
# this are fully null data in witch maximum=0 and minimum=0 so this are not useable data

# %%
#remove colum
data.drop(columns =["generation_gwh_2019","estimated_generation_gwh","generation_gwh_2013","wepp_id","other_fuel3"],inplace=True)

# %%
data.head(2)
# Out:
#   country country_long                 name   gppd_idnr  capacity_mw  \
# 0     IND        India     ACME Solar Tower  WRI1020239          2.5
# 1     IND        India  ADITYA CEMENT WORKS  WRI1019881         98.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
#
#                                                  url  \
# 0  http://www.nrel.gov/csp/solarpaces/project_det...
# 1                    http://www.ultratechcement.com/
#
#                      geolocation_source year_of_capacity_data  \
# 0  National Renewable Energy Laboratory                   NaN
# 1                                   WRI                   NaN
#
#   generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# ...

# %%
data.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# other_fuel2               906
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
data.drop(columns =["other_fuel2"],inplace=True)

# %% [markdown]
# remove the null valuse

# %%
data.name.unique
# Out:
# <bound method Series.unique of 0                  ACME Solar Tower
# 1               ADITYA CEMENT WORKS
# 2          AES Saurashtra Windfarms
# 3                       AGARTALA GT
# 4                      AKALTARA TPP
#                    ...
# 902                    YERMARUS TPP
# 903    Yelesandra Solar Power Plant
# 904    Yelisirur wind power project
# 905                     ZAWAR MINES
# 906         iEnergy Theni Wind Farm
# Name: name, Length: 907, dtype: object>

# %%
sns.countplot(data.name)
data["name"].value_counts()
# Out:
# SONAI MILL                                                     1
# Roaring 40s Wind Farms (Khandke) Private Limited - Phase II    1
# RAMPUR                                                         1
# Muradwala Dal Singh Solar Power Plant                          1
# NMDC Anehalu Wind Farm                                         1
#                                                               ..
# DNYANESHWAR MILL                                               1
# Jangi Wind Farm                                                1
# SHOLAYAR I&II                                                  1
# CHUTAK                                                         1
# Essel Mining Wind Farm                                         1
# Name: name, Length: 907, dtype: int64

# %%
sns.countplot(data.primary_fuel)
data["primary_fuel"].value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
sns.scatterplot(x = data.capacity_mw, y = data.primary_fuel, s = 150)
plt.title('Type of power plant and capacity');

# %% [markdown]
# The Hydro Power Plant has most of the high-capacity power plant

# %%
countries_capacity = data.groupby('country_long')[['capacity_mw']].sum().sort_values('capacity_mw', ascending = False).head(20)
countries_capacity
# Out:
#               capacity_mw
# country_long
# India          295884.946

# %%
sns.scatterplot(x = data.commissioning_year, y = data.primary_fuel, s = 150);
plt.title('Primary fuel and commission year')
# Out:
# Text(0.5, 1.0, 'Primary fuel and commission year')

# %% [markdown]
# the hydro power plant is the most popular among the other plants

# %%
nuclear_plant = data[data.primary_fuel.isin(['Nuclear'])]
number_of_nuclear_plant = nuclear_plant.name.value_counts()
number_of_nuclear_plant
# Out:
# TARAPUR          1
# KUNDANKULAM      1
# R.A.P.S.         1
# KAIGA            1
# N.A.P.S          1
# M.A.P.P.         1
# DAE RAJASTHAN    1
# Kudankulam       1
# KAKRAPARA        1
# Name: name, dtype: int64

# %%
sns.barplot(x = number_of_nuclear_plant.index, y = number_of_nuclear_plant)
plt.xticks(rotation = 90)
plt.title('Number of Nuclear Power Plants Around The country')
plt.ylabel('Number of Plants')
plt.xlabel('state');

# %%
print('There are {} state have total {} nuclear power plants.'.format(len(number_of_nuclear_plant), number_of_nuclear_plant.sum()))
# Out:
# There are 9 state have total 9 nuclear power plants.

# %%
Coal_plant = data[data.primary_fuel.isin(['Coal'])]
number_of_Coal_plant = Coal_plant.name.value_counts()
number_of_Coal_plant
# Out:
# YERMARUS TPP              1
# TORR POWER SAB.           1
# Shri Singaji MALWA TPP    1
# PAINAMPURAM               1
# MAQSOODPUR  IPP           1
#                          ..
# RAIGARH TPP               1
# MUNDRA TPP                1
# RIHAND                    1
# JAYPEE SIDHI CEMENT       1
# MEJA STPP                 1
# Name: name, Length: 258, dtype: int64

# %%
sns.barplot(x = number_of_Coal_plant.index, y = number_of_Coal_plant)
plt.xticks(rotation = 90)
plt.title('Number of Coal Power Plants Around The country')
plt.ylabel('Number of Plants')
plt.xlabel('state');

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.head(2)
# Out:
#   country country_long                 name   gppd_idnr  capacity_mw  \
# 0     IND        India     ACME Solar Tower  WRI1020239          2.5
# 1     IND        India  ADITYA CEMENT WORKS  WRI1019881         98.0
#
#    latitude  longitude primary_fuel other_fuel1  commissioning_year  ...  \
# 0   28.1839    73.2407        Solar         NaN              2011.0  ...
# 1   24.7663    74.6090         Coal         NaN                 NaN  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
#
#                                                  url  \
# 0  http://www.nrel.gov/csp/solarpaces/project_det...
# 1                    http://www.ultratechcement.com/
#
#                      geolocation_source year_of_capacity_data  \
# 0  National Renewable Energy Laboratory                   NaN
# 1                                   WRI                   NaN
#
# ...

# %%
data.shape
# Out:
# (907, 21)

# %%
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_data_source'],
#       dtype='object')

# %%
sns.countplot(data=data,y="name")
data["name"].value_counts()
# Out:
# SONAI MILL                                                     1
# Roaring 40s Wind Farms (Khandke) Private Limited - Phase II    1
# RAMPUR                                                         1
# Muradwala Dal Singh Solar Power Plant                          1
# NMDC Anehalu Wind Farm                                         1
#                                                               ..
# DNYANESHWAR MILL                                               1
# Jangi Wind Farm                                                1
# SHOLAYAR I&II                                                  1
# CHUTAK                                                         1
# Essel Mining Wind Farm                                         1
# Name: name, Length: 907, dtype: int64

# %%
data['other_fuel1'].fillna(data['other_fuel1'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1                 0
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 907 non-null    object
#  1   country_long            907 non-null    object
#  2   name                    907 non-null    object
#  3   gppd_idnr               907 non-null    object
#  4   capacity_mw             907 non-null    float64
#  5   latitude                861 non-null    float64
#  6   longitude               907 non-null    float64
#  7   primary_fuel            907 non-null    object
#  8   other_fuel1             907 non-null    object
#  9   commissioning_year      527 non-null    float64
#  10  owner                   907 non-null    object
#  11  source                  907 non-null    object
#  12  url                     907 non-null    object
#  13  geolocation_source      907 non-null    object
# ...

# %% [markdown]
# # remove null values in our data set

# %%
data['generation_data_source'].fillna(data['generation_data_source'].mode()[0],inplace=True)
data['geolocation_source'].fillna(data['geolocation_source'].mode()[0],inplace=True)
data['owner'].fillna(data['owner'].mode()[0],inplace=True)

# %%
data['generation_gwh_2018'].fillna(data['generation_gwh_2018'].mean(),inplace=True)
data['generation_gwh_2017'].fillna(data['generation_gwh_2017'].mean(),inplace=True)
data['generation_gwh_2016'].fillna(data['generation_gwh_2016'].mean(),inplace=True)
data['generation_gwh_2015'].fillna(data['generation_gwh_2015'].mean(),inplace=True)
data['generation_gwh_2014'].fillna(data['generation_gwh_2014'].mean(),inplace=True)
data['year_of_capacity_data'].fillna(data['year_of_capacity_data'].mean(),inplace=True)
data['commissioning_year'].fillna(data['commissioning_year'].mean(),inplace=True)
data['latitude'].fillna(data['latitude'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_gwh_2018       0
# generation_data_source    0
# dtype: int64

# %%
data.head(2)
# Out:
#   country country_long                 name   gppd_idnr  capacity_mw  \
# 0     IND        India     ACME Solar Tower  WRI1020239          2.5
# 1     IND        India  ADITYA CEMENT WORKS  WRI1019881         98.0
#
#    latitude  longitude primary_fuel other_fuel1  commissioning_year  ...  \
# 0   28.1839    73.2407        Solar         Oil         2011.000000  ...
# 1   24.7663    74.6090         Coal         Oil         1997.091082  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
#
#                                                  url  \
# 0  http://www.nrel.gov/csp/solarpaces/project_det...
# 1                    http://www.ultratechcement.com/
#
#                      geolocation_source year_of_capacity_data  \
# 0  National Renewable Energy Laboratory                2019.0
# 1                                   WRI                2019.0
#
# ...

# %% [markdown]
# # encode the dataset

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data["country"]=le.fit_transform(data["country"])
data["country_long"]=le.fit_transform(data["country_long"])
data["name"]=le.fit_transform(data["name"])
data["gppd_idnr"]=le.fit_transform(data["gppd_idnr"])
data["other_fuel1"]=le.fit_transform(data["other_fuel1"])
data["source"]=le.fit_transform(data["source"])
data["url"]=le.fit_transform(data["url"])
data["geolocation_source"]=le.fit_transform(data["geolocation_source"])
data["generation_data_source"]=le.fit_transform(data["generation_data_source"])
data["primary_fuel"]=le.fit_transform(data["primary_fuel"])
data["owner"]=le.fit_transform(data["owner"])

# %%
data.head(2)
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        657          2.5   28.1839    73.2407
# 1        0             0     1        519         98.0   24.7663    74.6090
#
#    primary_fuel  other_fuel1  commissioning_year  ...  source  url  \
# 0             3            2         2011.000000  ...     109  128
# 1             0            2         1997.091082  ...     174  173
#
#    geolocation_source  year_of_capacity_data  generation_gwh_2014  \
# 0                   1                 2019.0           2431.82359
# 1                   2                 2019.0           2431.82359
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0          2428.226946          2467.936859          2547.759305
# 1          2428.226946          2467.936859          2547.759305
#
#    generation_gwh_2018  generation_data_source
# 0          2600.804099                       0
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_data_source'],
#       dtype='object')

# %%
data.year_of_capacity_data
# Out:
# 0      2019.0
# 1      2019.0
# 2      2019.0
# 3      2019.0
# 4      2019.0
#         ...
# 902    2019.0
# 903    2019.0
# 904    2019.0
# 905    2019.0
# 906    2019.0
# Name: year_of_capacity_data, Length: 907, dtype: float64

# %%
data.describe()
# Out:
#        country  country_long        name   gppd_idnr  capacity_mw    latitude  \
# count    907.0         907.0  907.000000  907.000000   907.000000  907.000000
# mean       0.0           0.0  453.000000  453.000000   326.223755   21.197918
# std        0.0           0.0  261.972645  261.972645   590.085456    6.079148
# min        0.0           0.0    0.000000    0.000000     0.000000    8.168900
# 25%        0.0           0.0  226.500000  226.500000    16.725000   17.072000
# 50%        0.0           0.0  453.000000  453.000000    59.200000   21.281800
# 75%        0.0           0.0  679.500000  679.500000   385.250000   25.176450
# max        0.0           0.0  906.000000  906.000000  4760.000000   34.649000
#
#         longitude  primary_fuel  other_fuel1  commissioning_year  ...  \
# count  907.000000    907.000000   907.000000          907.000000  ...
# mean    77.464907      3.113561     1.995590         1997.091082  ...
# ...

# %% [markdown]
# # split the data

# %%
x=data.drop("capacity_mw",axis=1)
y=data['capacity_mw']

# %%
x
# Out:
#      country  country_long  name  gppd_idnr  latitude  longitude  \
# 0          0             0     0        657   28.1839    73.2407
# 1          0             0     1        519   24.7663    74.6090
# 2          0             0     2        853   21.9038    69.3732
# 3          0             0     3          0   23.8712    91.3602
# 4          0             0     4          1   21.9603    82.4091
# ..       ...           ...   ...        ...       ...        ...
# 902        0             0   902        491   16.2949    77.3568
# 903        0             0   903        822   12.8932    78.1654
# 904        0             0   904        891   15.2758    75.5811
# 905        0             0   905        539   24.3500    73.7477
# 906        0             0   906        876    9.9344    77.4768
#
#      primary_fuel  other_fuel1  commissioning_year  owner  source  url  \
# 0               3            2         2011.000000    229     109  128
# ...

# %%
y.head(5)
# Out:
# 0       2.5
# 1      98.0
# 2      39.2
# 3     135.0
# 4    1800.0
# Name: capacity_mw, dtype: float64

# %%
x.shape
# Out:
# (907, 20)

# %%
y.shape
# Out:
# (907,)

# %%
data.primary_fuel.unique()
# Out:
# array([3, 0, 1, 2, 7, 6, 4, 5], dtype=int64)

# %%
#data.loc[data['primary_fuel']=='Coal','primary_fuel'] = 1    
#data.loc[data['primary_fuel']=='Wind','primary_fuel'] = 2
#data.loc[data['primary_fuel']=='Gas','primary_fuel'] = 3   #converting the data into int form like 0,1 also we can use the lable incoding
#data.loc[data['primary_fuel']=='Solar','primary_fuel']=4
#data.loc[data['primary_fuel']=='Oil','primary_fuel'] = 5   
#data.loc[data['primary_fuel']=='Nuclear','primary_fuel']= 6
#data.loc[data['primary_fuel']=='Biomass','primary_fuel']= 7   
#data.loc[data['primary_fuel']=='Hydro','primary_fuel']= 8

# %%
data.head(20)
# Out:
#     country  country_long  name  gppd_idnr  capacity_mw   latitude  longitude  \
# 0         0             0     0        657         2.50  28.183900  73.240700
# 1         0             0     1        519        98.00  24.766300  74.609000
# 2         0             0     2        853        39.20  21.903800  69.373200
# 3         0             0     3          0       135.00  23.871200  91.360200
# 4         0             0     4          1      1800.00  21.960300  82.409100
# 5         0             0     5          2       250.00  23.768900  68.644700
# 6         0             0     6          3        60.00  10.454700  77.007800
# 7         0             0     7          4       192.00  32.225800  77.207000
# 8         0             0     8          5       290.00  16.330000  75.886300
# 9         0             0     9          6       210.00  23.164200  81.637300
# 10        0             0    10          7      1350.00  21.078200  77.900900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 907 non-null    int64
#  1   country_long            907 non-null    int64
#  2   name                    907 non-null    int64
#  3   gppd_idnr               907 non-null    int64
#  4   capacity_mw             907 non-null    float64
#  5   latitude                907 non-null    float64
#  6   longitude               907 non-null    float64
#  7   primary_fuel            907 non-null    int64
#  8   other_fuel1             907 non-null    int64
#  9   commissioning_year      907 non-null    float64
#  10  owner                   907 non-null    int32
#  11  source                  907 non-null    int64
#  12  url                     907 non-null    int64
#  13  geolocation_source      907 non-null    int64
# ...

# %% [markdown]
# # scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc
# Out:
# StandardScaler()

# %%
data=sc.fit_transform(x)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
svm=SVR()
lr=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
lr=LogisticRegression()

# %% [markdown]
# its regresion problem we have perfom the model according to the problem
