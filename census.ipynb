# %%
#import the requred library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#upload the dataset or file
df=pd.read_csv('census.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#check the type of our dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#check the columns
df.keys()
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#check the null values in our data set
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#check the shape of data like how many rows and columns are in our dataset
df.shape
# Out:
# (32560, 15)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [raw]
# The age column has a range of 17 to 90
# The age cFnlwgt has a range of 1.228500 to 1.484705
# The education number has a range of 1 to 16
# The capital gain starts from 0 and ends at 99999
# The capital loss starts at 0 and ends at 4356
# Hours per week range between 1–99.

# %%
sns.distplot(df.Age)
df["Age"].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64

# %% [markdown]
# our data is has right skewness, with majority of the ages falling in the 20–50.
# The count keeps on decreasing as the age increases.

# %%
df.head(2)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
#
#         Marital_status          Occupation    Relationship    Race    Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K

# %%
plt.figure(figsize=(12,7))
sns.countplot(df.Workclass)
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# majority of the people belong to ‘Private’ sector workclass

# %%
plt.figure(figsize=(18,10))
sns.countplot(df.Education)
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %% [markdown]
# no missing values in our datadet also the majority HS-gred,also Some-college and
#  Bachelors

# %%
plt.figure(figsize=(18,10))
sns.countplot(df.Education_num)
df['Education_num'].value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64

# %% [markdown]
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64

# %% [markdown]
# education and education _num both are similar

# %%
plt.figure(figsize=(12,7))
sns.countplot(df.Marital_status)
df['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %% [markdown]
# Majority of the people have  "Married-civ-spouse", and lowest is  "Married-AF-spouse".

# %%
plt.figure(figsize=(25,10))
sns.countplot(df.Occupation)
df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %% [markdown]
# there is also ? missing value so occupation also show ? columns

# %%
plt.figure(figsize=(10,7))
sns.countplot(df.Relationship)
df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %% [markdown]
# with highest number set for ‘Husband’ and lowest for "Other-relative".

# %%
plt.figure(figsize=(12,7))
sns.countplot(df.Race)
df['Race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %% [markdown]
# Highest number of people have race as White

# %%
plt.figure(figsize=(12,7))
sns.distplot(df.Capital_gain)
df["Capital_gain"].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1639         1
# 5060         1
# 6097         1
# 1455         1
# 7978         1
# Name: Capital_gain, Length: 119, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.countplot(df.Sex)
df["Sex"].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.distplot(df.Capital_loss)
df["Capital_loss"].value_counts()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1485       51
#         ...
# 2467        1
# 1539        1
# 155         1
# 2282        1
# 1411        1
# Name: Capital_loss, Length: 92, dtype: int64

# %% [markdown]
# The "Capital_loss" column also has majority of the values set as 0,  The data is highly right skewed

# %%
plt.figure(figsize=(10,5))
sns.distplot(df.Hours_per_week)
df["Hours_per_week"].value_counts()
# Out:
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 92        1
# 74        1
# 94        1
# 82        1
# 87        1
# Name: Hours_per_week, Length: 94, dtype: int64

# %%
plt.figure(figsize=(20,7))
sns.countplot(df.Native_country)
df["Native_country"].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
plt.figure(figsize=(10,7))
sns.countplot(df.Income)
df["Income"].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
sns.countplot(x='Sex',hue="Income", data=df)
df["Sex"].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %% [markdown]
# comaprison in male income and female income, Males have a higher chance of earning more than 50K, than females

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Workclass',hue="Income", data=df)
df["Workclass"].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# comparison in salary and warkclass people private people gat higer

# %%
plt.figure(figsize=(22,7))
sns.countplot(x='Education',hue="Income", data=df)
df["Education"].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Education_num',hue="Income", data=df)
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Marital_status',hue="Income", data=df)
df["Marital_status"].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Relationship',hue="Income", data=df)
df["Relationship"].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
plt.figure(figsize=(22,7))
sns.countplot(x='Occupation',hue="Income", data=df)
df["Occupation"].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
sns.heatmap(df.corr().isnull())
# Out:
# <AxesSubplot:>

# %%
df.head(50)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
#Finding the special characters in the data frame 
df.isin(['?']).sum(axis=0)
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.head(2)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
#
#         Marital_status          Occupation    Relationship    Race    Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K

# %%
sns.countplot(df.Occupation)
df['Occupation'].value_counts()   #spacial charater "?" present in our dtaset
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
df.skew()
# Out:
# Age                0.558738
# Fnlwgt             1.446972
# Education_num     -0.311630
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# dtype: float64

# %%
# converting dtype to string 
df["Occupation"]= df["Occupation"].astype(str) 
# removing '.' 
df["Occupation"]= df["Occupation"].str.replace("?", "prof-specialty")

# %%
sns.countplot(df.Occupation)
df["Occupation"].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  prof-specialty       1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
# converting dtype to string 
df["Workclass"]= df["Workclass"].astype(str) 
# removing '.' 
df["Workclass"]= df["Workclass"].str.replace("?", "private")

# %%
sns.countplot(df.Occupation)
df["Workclass"].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  private              1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
# converting dtype to string 
df["Native_country"]= df["Native_country"].astype(str) 
# removing '.' 
df["Native_country"]= df["Native_country"].str.replace("?", " United-States ")

# %%
sns.countplot(df.Occupation)
df["Native_country"].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#   United-States                  583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [raw]
# now no spacial charecter in our data set

# %%
df.head(50)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
sns.boxplot(x="Workclass",y="Age",data=df)
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='Age'>

# %%
sns.boxplot(y="Age",data=df)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(y="Fnlwgt",data=df)
# Out:
# <AxesSubplot:ylabel='Fnlwgt'>

# %% [markdown]
# outlier present in our dataset

# %%
df['Income'].unique()
df['Income'] = [1 if value == ' >50K' else 0 for value in df['Income'].values]
df['Income'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.head(2)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
#
#         Marital_status          Occupation    Relationship    Race    Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States       0
# 1             0             0              40   United-States       0

# %% [markdown]
# Apply label incodinf

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["Workclass"]=le.fit_transform(df["Workclass"])
df["Education"]=le.fit_transform(df["Education"])
df["Marital_status"]=le.fit_transform(df["Marital_status"])
df["Occupation"]=le.fit_transform(df["Occupation"])
df["Relationship"]=le.fit_transform(df["Relationship"])
df["Race"]=le.fit_transform(df["Race"])
df["Sex"]=le.fit_transform(df["Sex"])
df["Native_country"]=le.fit_transform(df["Native_country"])

# %%
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5   83311          9             13               2
# 1   38          3  215646         11              9               0
# 2   53          3  234721          1              7               2
# 3   28          3  338409          9             13               2
# 4   37          3  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           3             0     4    1             0             0
# 1           5             1     4    1             0             0
# 2           5             0     2    1             0             0
# 3           9             5     2    0             0             0
# 4           3             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %%
df.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000   32560.000000
# mean      38.581634      3.376290  1.897818e+05     10.298249      10.080590
# std       13.640642      1.581995  1.055498e+05      3.870317       2.572709
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      3.000000  1.178315e+05      9.000000       9.000000
# 50%       37.000000      3.000000  1.783630e+05     11.000000      10.000000
# 75%       48.000000      3.000000  2.370545e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         2.611794      6.421959      1.446376      3.665848      0.669195
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # split the data in independent and dependent variable

# %%
x=df.drop("Income",axis=1)
y=df['Income']

# %%
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 32560, dtype: int64

# %% [markdown]
# remove outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Age                   20.0
# Workclass              0.0
# Fnlwgt            119223.0
# Education              3.0
# Education_num          3.0
# Marital_status         2.0
# Occupation             7.0
# Relationship           3.0
# Race                   0.0
# Sex                    1.0
# Capital_gain           0.0
# Capital_loss           0.0
# Hours_per_week         5.0
# Native_country         0.0
# Income                 0.0
# dtype: float64

# %%
df.boxplot(column='Fnlwgt')
# Out:
# <AxesSubplot:>

# %%
print(df['Fnlwgt'].quantile(0.10))
print(df['Fnlwgt'].quantile(0.90))
# Out:
# 65715.0
# 329054.5

# %%
df["Fnlwgt"] = np.where(df["Fnlwgt"] <65715.0, 65715.0,df['Fnlwgt'])
df["Fnlwgt"] = np.where(df["Fnlwgt"] >329054.5, 329054.5,df['Fnlwgt'])
print(df['Fnlwgt'].skew())
# Out:
# 0.31689095203360024

# %% [markdown]
# # scallig the data

# %% [markdown]
# there are certain columns have very small values and some columns have high values.
# This process is important  values on a similar scale allow the model to learn better.

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc
# Out:
# StandardScaler()

# %%
data=sc.fit_transform(x)

# %% [markdown]
# # now fiting data in to classification model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
dtc=DecisionTreeClassifier()
gnb=GaussianNB()
svm=SVC()
lr=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
classifier = DecisionTreeClassifier() 
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print("accuracy score",accuracy_score(y_test, y_pred))
# Out:
# accuracy score 0.8083538083538083

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      7395
#            1       0.60      0.61      0.61      2373
#
#     accuracy                           0.81      9768
#    macro avg       0.74      0.74      0.74      9768
# weighted avg       0.81      0.81      0.81      9768

# %%
gnb=GaussianNB()
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print("accuracy score",accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy score 0.8057944307944308
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      7395
#            1       0.60      0.61      0.60      2373
#
#     accuracy                           0.81      9768
#    macro avg       0.74      0.74      0.74      9768
# weighted avg       0.81      0.81      0.81      9768

# %%
svm=SVC()
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print("accuracy score",accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy score 0.8081490581490581
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      7395
#            1       0.60      0.61      0.61      2373
#
#     accuracy                           0.81      9768
#    macro avg       0.74      0.74      0.74      9768
# weighted avg       0.81      0.81      0.81      9768

# %%
lr=LogisticRegression()
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print("accuracy score",accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy score 0.8064086814086814
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      7395
#            1       0.60      0.61      0.61      2373
#
#     accuracy                           0.81      9768
#    macro avg       0.74      0.74      0.74      9768
# weighted avg       0.81      0.81      0.81      9768

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.7940212940212941
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      7395
#            1       0.76      0.22      0.34      2373
#
#     accuracy                           0.79      9768
#    macro avg       0.78      0.60      0.61      9768
# weighted avg       0.79      0.79      0.75      9768

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.7940212940212941
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      7395
#            1       0.76      0.22      0.34      2373
#
#     accuracy                           0.79      9768
#    macro avg       0.78      0.60      0.61      9768
# weighted avg       0.79      0.79      0.75      9768

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingClassifier

# %%
gd=GradientBoostingClassifier()

# %%
for i in range(2,7):
    cv=cross_val_score(gd,x,y,cv=i)
    print(gd,cv.mean())
# Out:
# GradientBoostingClassifier() 0.8647420147420147
# GradientBoostingClassifier() 0.8645885489857528
# GradientBoostingClassifier() 0.8650184275184275
# GradientBoostingClassifier() 0.8638820638820638
# GradientBoostingClassifier() 0.8644350374560058

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.figure(figsize=(6,4))
plt.plot(fpr,tpr,'-g',linewidth=2,markersize=12)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for  Model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()
